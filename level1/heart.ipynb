# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('heart.csv')

df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# STEP 1 IS EDA

# %%
df.shape
# Out:
# (918, 12)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                   str
# ChestPainType         str
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG            str
# MaxHR               int64
# ExerciseAngina        str
# Oldpeak           float64
# ST_Slope              str
# HeartDisease        int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts()
# TO CHECK WHETHER WE CAN USE THIS DATA OR NOT SO THE DATA IS BALANCED BECAUSE IT HAS BOTH 1 AND 0 IN THE OUTPUT FOR VALID AMOUNT
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var, num):
    plt.subplot(2,2, num)
    sns.histplot(df[var], kde=True)

plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)
plt.tight_layout()

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 223     10
# 220     10
# 211      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()  


df['Cholesterol'] = df['Cholesterol'].replace(0, ch_mean)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %%
restingbp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()
df['RestingBP'] = df['RestingBP'].replace(0, restingbp_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %% [markdown]
# THIS IS HOW YOU GET TO DRAW SUBPLOT

# %%
def plotting(var, num):
    plt.subplot(2,2, num)
    sns.histplot(df[var], kde=True)

plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)
plt.tight_layout()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# DATAPREPROCESSING AND DATA CLEANING

# %%
df_encode = pd.get_dummies(df, drop_first=True)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40      140.0        289.0          0    172      0.0             0
# 1     49      160.0        180.0          0    156      1.0             1
# 2     37      130.0        283.0          0     98      0.0             0
# 3     48      138.0        214.0          0    108      1.5             1
# 4     54      150.0        195.0          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45      110.0        264.0          0    132      1.2             1
# 914   68      144.0        193.0          1    141      3.4             1
# 915   57      130.0        131.0          0    115      1.2             1
# 916   57      130.0        236.0          0    174      0.0             1
# 917   38      138.0        175.0          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
#df_encode['Sex_M'] = df_encode['Sex_M'].replace({True: 1, False: 0}, inplace=True)
#df_encode['ChesChestPainType_ATA'].replace({True: 1, False: 0}, inplace=True)

df_encode = df_encode.astype(int)
df_encode.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172        0             0
# 1   49        160          180          0    156        1             1
# 2   37        130          283          0     98        0             0
# 3   48        138          214          0    108        1             1
# 4   54        150          195          0    122        0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...
